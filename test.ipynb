# %% [markdown]
# ### Example Tutorial

# %%
import pandas as pd

import request_api as reqdata
import pandas_init as pd_init
from config.config import Weather_API_KEY

# %%
city = "Ankara"
country_code = 'TR'

lat,long = reqdata.get_lat_log(city, country_code)

# %%
# this variables is unix time, UTC time zone

start= 1609168752 
end = 1703776752

# %%
current_response,forecast_response,historical_response = reqdata.request_init(lat,long,start,end)
# Out:
# {'coord': {'lon': 32.854, 'lat': 39.9208},
#  'list': [{'main': {'aqi': 5},
#    'components': {'co': 1108.17,
#     'no': 91.2,
#     'no2': 77.46,
#     'o3': 0,
#     'so2': 80.11,
#     'pm2_5': 154.36,
#     'pm10': 170.36,
#     'nh3': 26.09},
#    'dt': 1703788924}]}

# %%
forecast_response
# Out:
# {'coord': {'lon': 32.854, 'lat': 39.9208},
#  'list': [{'main': {'aqi': 5},
#    'components': {'co': 1081.47,
#     'no': 112.65,
#     'no2': 71.29,
#     'o3': 0,
#     'so2': 61.99,
#     'pm2_5': 134.4,
#     'pm10': 149.25,
#     'nh3': 19},
#    'dt': 1703786400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1108.17,
#     'no': 91.2,
#     'no2': 77.46,
#     'o3': 0,
#     'so2': 80.11,
#     'pm2_5': 154.36,
#     'pm10': 170.36,
#     'nh3': 26.09},
#    'dt': 1703790000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1054.76,
#     'no': 67.06,
#     'no2': 78.83,
#     'o3': 0,
#     'so2': 92.51,
#     'pm2_5': 159.6,
#     'pm10': 175.15,
#     'nh3': 30.65},
#    'dt': 1703793600},
#   {'main': {'aqi': 5},
#    'components': {'co': 961.3,
#     'no': 49.62,
#     'no2': 74.03,
#     'o3': 0,
#     'so2': 92.51,
#     'pm2_5': 149.41,
#     'pm10': 163.46,
#     'nh3': 31.16},
#    'dt': 1703797200},
#   {'main': {'aqi': 5},
#    'components': {'co': 867.84,
#     'no': 38.89,
#     'no2': 70.6,
#     'o3': 0,
#     'so2': 83.92,
#     'pm2_5': 132.23,
#     'pm10': 144.19,
#     'nh3': 28.88},
#    'dt': 1703800800},
#   {'main': {'aqi': 5},
#    'components': {'co': 767.71,
#     'no': 26.6,
#     'no2': 65.8,
#     'o3': 0.02,
#     'so2': 73.43,
#     'pm2_5': 114.1,
#     'pm10': 124.21,
#     'nh3': 25.84},
#    'dt': 1703804400},
#   {'main': {'aqi': 5},
#    'components': {'co': 667.57,
#     'no': 14.08,
#     'no2': 60.32,
#     'o3': 0.23,
#     'so2': 61.99,
#     'pm2_5': 96.16,
#     'pm10': 104.54,
#     'nh3': 22.04},
#    'dt': 1703808000},
#   {'main': {'aqi': 5},
#    'components': {'co': 594.14,
#     'no': 5.09,
#     'no2': 54.84,
#     'o3': 1.68,
#     'so2': 51.98,
#     'pm2_5': 82.17,
#     'pm10': 89.34,
#     'nh3': 19.51},
#    'dt': 1703811600},
#   {'main': {'aqi': 5},
#    'components': {'co': 554.09,
#     'no': 1.5,
#     'no2': 50.04,
#     'o3': 5.1,
#     'so2': 48.16,
#     'pm2_5': 75.06,
#     'pm10': 81.66,
#     'nh3': 19},
#    'dt': 1703815200},
#   {'main': {'aqi': 4},
#    'components': {'co': 540.73,
#     'no': 0.89,
#     'no2': 47.3,
#     'o3': 7.96,
#     'so2': 48.64,
#     'pm2_5': 72.31,
#     'pm10': 78.68,
#     'nh3': 19.25},
#    'dt': 1703818800},
#   {'main': {'aqi': 4},
#    'components': {'co': 540.73,
#     'no': 1.43,
#     'no2': 47.98,
#     'o3': 7.78,
#     'so2': 50.07,
#     'pm2_5': 70.98,
#     'pm10': 77.3,
#     'nh3': 19.25},
#    'dt': 1703822400},
#   {'main': {'aqi': 5},
#    'components': {'co': 640.87,
#     'no': 12.96,
#     'no2': 56.89,
#     'o3': 1.11,
#     'so2': 55.79,
#     'pm2_5': 84.09,
#     'pm10': 92.04,
#     'nh3': 21.03},
#    'dt': 1703826000},
#   {'main': {'aqi': 5},
#    'components': {'co': 867.84,
#     'no': 50.52,
#     'no2': 65.8,
#     'o3': 0.23,
#     'so2': 61.99,
#     'pm2_5': 110.52,
#     'pm10': 121.61,
#     'nh3': 24.32},
#    'dt': 1703829600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1094.82,
#     'no': 94.77,
#     'no2': 70.6,
#     'o3': 3.71,
#     'so2': 54.84,
#     'pm2_5': 139.32,
#     'pm10': 152.96,
#     'nh3': 17.48},
#    'dt': 1703833200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1241.68,
#     'no': 121.59,
#     'no2': 71.29,
#     'o3': 7.87,
#     'so2': 50.55,
#     'pm2_5': 161.85,
#     'pm10': 177,
#     'nh3': 12.92},
#    'dt': 1703836800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1308.44,
#     'no': 126.96,
#     'no2': 75.4,
#     'o3': 11.44,
#     'so2': 47.68,
#     'pm2_5': 177.79,
#     'pm10': 193.4,
#     'nh3': 10.26},
#    'dt': 1703840400},
#   {'main': {'aqi': 5},
#    'components': {'co': 821.11,
#     'no': 54.09,
#     'no2': 65.12,
#     'o3': 26.46,
#     'so2': 50.07,
#     'pm2_5': 103.6,
#     'pm10': 112.13,
#     'nh3': 4.69},
#    'dt': 1703844000},
#   {'main': {'aqi': 5},
#    'components': {'co': 700.95,
#     'no': 37.55,
#     'no2': 63.06,
#     'o3': 34.69,
#     'so2': 52.93,
#     'pm2_5': 89.95,
#     'pm10': 97.38,
#     'nh3': 2.47},
#    'dt': 1703847600},
#   {'main': {'aqi': 5},
#    'components': {'co': 654.22,
#     'no': 29.95,
#     'no2': 64.43,
#     'o3': 36.84,
#     'so2': 52.93,
#     'pm2_5': 85.51,
#     'pm10': 92.6,
#     'nh3': 1.55},
#    'dt': 1703851200},
#   {'main': {'aqi': 5},
#    'components': {'co': 734.33,
#     'no': 38,
#     'no2': 78.83,
#     'o3': 22.89,
#     'so2': 49.11,
#     'pm2_5': 98.7,
#     'pm10': 106.9,
#     'nh3': 2.88},
#    'dt': 1703854800},
#   {'main': {'aqi': 5},
#    'components': {'co': 921.25,
#     'no': 65.27,
#     'no2': 94.59,
#     'o3': 5.23,
#     'so2': 48.16,
#     'pm2_5': 126.04,
#     'pm10': 136.55,
#     'nh3': 5.51},
#    'dt': 1703858400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1134.87,
#     'no': 107.29,
#     'no2': 104.19,
#     'o3': 0.08,
#     'so2': 53.41,
#     'pm2_5': 151.38,
#     'pm10': 163.98,
#     'nh3': 8.23},
#    'dt': 1703862000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1361.85,
#     'no': 153.78,
#     'no2': 111.04,
#     'o3': 0,
#     'so2': 68.67,
#     'pm2_5': 174.48,
#     'pm10': 189.17,
#     'nh3': 12.16},
#    'dt': 1703865600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1535.42,
#     'no': 185.97,
#     'no2': 115.16,
#     'o3': 0,
#     'so2': 85.83,
#     'pm2_5': 197.53,
#     'pm10': 214.55,
#     'nh3': 16.97},
#    'dt': 1703869200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1655.58,
#     'no': 198.48,
#     'no2': 115.16,
#     'o3': 0,
#     'so2': 101.09,
#     'pm2_5': 221.99,
#     'pm10': 242.27,
#     'nh3': 22.04},
#    'dt': 1703872800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1695.63,
#     'no': 189.54,
#     'no2': 111.04,
#     'o3': 0,
#     'so2': 111.58,
#     'pm2_5': 236.8,
#     'pm10': 259.86,
#     'nh3': 26.09},
#    'dt': 1703876400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1628.88,
#     'no': 162.72,
#     'no2': 100.08,
#     'o3': 0,
#     'so2': 109.67,
#     'pm2_5': 235.01,
#     'pm10': 259.69,
#     'nh3': 26.6},
#    'dt': 1703880000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1495.36,
#     'no': 134.11,
#     'no2': 87.05,
#     'o3': 0,
#     'so2': 85.83,
#     'pm2_5': 219.59,
#     'pm10': 243.32,
#     'nh3': 21.03},
#    'dt': 1703883600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1348.5,
#     'no': 110.87,
#     'no2': 78.14,
#     'o3': 0,
#     'so2': 55.79,
#     'pm2_5': 198.43,
#     'pm10': 219.36,
#     'nh3': 13.05},
#    'dt': 1703887200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1174.93,
#     'no': 83.15,
#     'no2': 71.29,
#     'o3': 0,
#     'so2': 54.36,
#     'pm2_5': 171.58,
#     'pm10': 188.07,
#     'nh3': 13.93},
#    'dt': 1703890800},
#   {'main': {'aqi': 5},
#    'components': {'co': 974.66,
#     'no': 51.86,
#     'no2': 65.12,
#     'o3': 0,
#     'so2': 48.64,
#     'pm2_5': 138.81,
#     'pm10': 148.99,
#     'nh3': 12.67},
#    'dt': 1703894400},
#   {'main': {'aqi': 5},
#    'components': {'co': 814.44,
#     'no': 31.29,
#     'no2': 60.32,
#     'o3': 0.01,
#     'so2': 43.87,
#     'pm2_5': 114.52,
#     'pm10': 120.66,
#     'nh3': 11.78},
#    'dt': 1703898000},
#   {'main': {'aqi': 5},
#    'components': {'co': 727.65,
#     'no': 20.56,
#     'no2': 56.89,
#     'o3': 0.03,
#     'so2': 41.49,
#     'pm2_5': 101.9,
#     'pm10': 106.39,
#     'nh3': 11.53},
#    'dt': 1703901600},
#   {'main': {'aqi': 5},
#    'components': {'co': 680.92,
#     'no': 15.42,
#     'no2': 53.47,
#     'o3': 0.06,
#     'so2': 39.1,
#     'pm2_5': 93.89,
#     'pm10': 97.79,
#     'nh3': 11.15},
#    'dt': 1703905200},
#   {'main': {'aqi': 5},
#    'components': {'co': 640.87,
#     'no': 12.85,
#     'no2': 48.67,
#     'o3': 0.15,
#     'so2': 31.47,
#     'pm2_5': 86.93,
#     'pm10': 90.83,
#     'nh3': 9.5},
#    'dt': 1703908800},
#   {'main': {'aqi': 5},
#    'components': {'co': 680.92,
#     'no': 21.46,
#     'no2': 47.3,
#     'o3': 0.04,
#     'so2': 32.42,
#     'pm2_5': 91.21,
#     'pm10': 96.05,
#     'nh3': 10.01},
#    'dt': 1703912400},
#   {'main': {'aqi': 5},
#    'components': {'co': 801.09,
#     'no': 44.7,
#     'no2': 50.72,
#     'o3': 0.03,
#     'so2': 38.15,
#     'pm2_5': 105.73,
#     'pm10': 111.62,
#     'nh3': 12.03},
#    'dt': 1703916000},
#   {'main': {'aqi': 5},
#    'components': {'co': 881.2,
#     'no': 61.69,
#     'no2': 54.15,
#     'o3': 0.32,
#     'so2': 40.05,
#     'pm2_5': 111.19,
#     'pm10': 117.85,
#     'nh3': 11.27},
#    'dt': 1703919600},
#   {'main': {'aqi': 5},
#    'components': {'co': 894.55,
#     'no': 65.27,
#     'no2': 54.15,
#     'o3': 0.84,
#     'so2': 32.9,
#     'pm2_5': 108.2,
#     'pm10': 116.02,
#     'nh3': 6.97},
#    'dt': 1703923200},
#   {'main': {'aqi': 5},
#    'components': {'co': 881.2,
#     'no': 66.16,
#     'no2': 54.15,
#     'o3': 1.29,
#     'so2': 30.28,
#     'pm2_5': 103.37,
#     'pm10': 111.43,
#     'nh3': 5.13},
#    'dt': 1703926800},
#   {'main': {'aqi': 4},
#    'components': {'co': 620.84,
#     'no': 26.15,
#     'no2': 57.58,
#     'o3': 7.06,
#     'so2': 36.72,
#     'pm2_5': 68.62,
#     'pm10': 74.42,
#     'nh3': 2.63},
#    'dt': 1703930400},
#   {'main': {'aqi': 4},
#    'components': {'co': 560.76,
#     'no': 16.54,
#     'no2': 59.63,
#     'o3': 11.09,
#     'so2': 36.72,
#     'pm2_5': 59.14,
#     'pm10': 64.47,
#     'nh3': 2.12},
#    'dt': 1703934000},
#   {'main': {'aqi': 4},
#    'components': {'co': 547.41,
#     'no': 14.98,
#     'no2': 61.01,
#     'o3': 11.8,
#     'so2': 36.72,
#     'pm2_5': 54.82,
#     'pm10': 60.31,
#     'nh3': 2.28},
#    'dt': 1703937600},
#   {'main': {'aqi': 4},
#    'components': {'co': 620.84,
#     'no': 26.38,
#     'no2': 67.86,
#     'o3': 5.68,
#     'so2': 42.44,
#     'pm2_5': 61.64,
#     'pm10': 68.18,
#     'nh3': 4.05},
#    'dt': 1703941200},
#   {'main': {'aqi': 5},
#    'components': {'co': 767.71,
#     'no': 52.75,
#     'no2': 77.46,
#     'o3': 0.87,
#     'so2': 54.84,
#     'pm2_5': 77.72,
#     'pm10': 85.88,
#     'nh3': 7.28},
#    'dt': 1703944800},
#   {'main': {'aqi': 5},
#    'components': {'co': 934.6,
#     'no': 87.62,
#     'no2': 85,
#     'o3': 0.03,
#     'so2': 66.76,
#     'pm2_5': 94.76,
#     'pm10': 104.55,
#     'nh3': 10.89},
#    'dt': 1703948400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1094.82,
#     'no': 118.02,
#     'no2': 89.11,
#     'o3': 0,
#     'so2': 74.39,
#     'pm2_5': 110.3,
#     'pm10': 121.6,
#     'nh3': 13.93},
#    'dt': 1703952000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1188.28,
#     'no': 128.75,
#     'no2': 89.11,
#     'o3': 0,
#     'so2': 79.16,
#     'pm2_5': 125.89,
#     'pm10': 139.04,
#     'nh3': 16.47},
#    'dt': 1703955600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1228.33,
#     'no': 128.75,
#     'no2': 87.05,
#     'o3': 0,
#     'so2': 82.97,
#     'pm2_5': 140.96,
#     'pm10': 155.97,
#     'nh3': 19},
#    'dt': 1703959200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1214.98,
#     'no': 113.55,
#     'no2': 80.88,
#     'o3': 0,
#     'so2': 82.97,
#     'pm2_5': 149.59,
#     'pm10': 165.98,
#     'nh3': 20.77},
#    'dt': 1703962800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1148.22,
#     'no': 92.09,
#     'no2': 73.34,
#     'o3': 0,
#     'so2': 79.16,
#     'pm2_5': 150.42,
#     'pm10': 167.51,
#     'nh3': 21.28},
#    'dt': 1703966400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1054.76,
#     'no': 74.21,
#     'no2': 65.12,
#     'o3': 0,
#     'so2': 69.62,
#     'pm2_5': 144.9,
#     'pm10': 161.51,
#     'nh3': 19.51},
#    'dt': 1703970000},
#   {'main': {'aqi': 5},
#    'components': {'co': 974.66,
#     'no': 60.8,
#     'no2': 59.63,
#     'o3': 0,
#     'so2': 50.55,
#     'pm2_5': 134.68,
#     'pm10': 149.54,
#     'nh3': 14.44},
#    'dt': 1703973600},
#   {'main': {'aqi': 5},
#    'components': {'co': 881.2,
#     'no': 46.05,
#     'no2': 54.84,
#     'o3': 0,
#     'so2': 42.92,
#     'pm2_5': 121.62,
#     'pm10': 134.27,
#     'nh3': 12.67},
#    'dt': 1703977200},
#   {'main': {'aqi': 5},
#    'components': {'co': 767.71,
#     'no': 30.4,
#     'no2': 51.41,
#     'o3': 0.01,
#     'so2': 38.62,
#     'pm2_5': 108.43,
#     'pm10': 117.46,
#     'nh3': 11.27},
#    'dt': 1703980800},
#   {'main': {'aqi': 5},
#    'components': {'co': 700.95,
#     'no': 21.46,
#     'no2': 48.67,
#     'o3': 0.02,
#     'so2': 36.72,
#     'pm2_5': 101.23,
#     'pm10': 108.34,
#     'nh3': 10.77},
#    'dt': 1703984400},
#   {'main': {'aqi': 5},
#    'components': {'co': 680.92,
#     'no': 17.66,
#     'no2': 46.61,
#     'o3': 0.04,
#     'so2': 34.81,
#     'pm2_5': 100.21,
#     'pm10': 106.04,
#     'nh3': 10.39},
#    'dt': 1703988000},
#   {'main': {'aqi': 5},
#    'components': {'co': 667.57,
#     'no': 16.09,
#     'no2': 44.55,
#     'o3': 0.04,
#     'so2': 30.28,
#     'pm2_5': 100.53,
#     'pm10': 104.66,
#     'nh3': 9.63},
#    'dt': 1703991600},
#   {'main': {'aqi': 5},
#    'components': {'co': 660.9,
#     'no': 16.32,
#     'no2': 42.84,
#     'o3': 0.06,
#     'so2': 26.94,
#     'pm2_5': 99.38,
#     'pm10': 102.63,
#     'nh3': 8.99},
#    'dt': 1703995200},
#   {'main': {'aqi': 5},
#    'components': {'co': 720.98,
#     'no': 27.49,
#     'no2': 43.18,
#     'o3': 0.01,
#     'so2': 30.52,
#     'pm2_5': 108.69,
#     'pm10': 112.45,
#     'nh3': 10.01},
#    'dt': 1703998800},
#   {'main': {'aqi': 5},
#    'components': {'co': 847.82,
#     'no': 52.3,
#     'no2': 46.61,
#     'o3': 0.02,
#     'so2': 35.76,
#     'pm2_5': 126.11,
#     'pm10': 130.64,
#     'nh3': 12.03},
#    'dt': 1704002400},
#   {'main': {'aqi': 5},
#    'components': {'co': 947.95,
#     'no': 72.42,
#     'no2': 50.72,
#     'o3': 0.25,
#     'so2': 37.19,
#     'pm2_5': 136.57,
#     'pm10': 141.56,
#     'nh3': 10.89},
#    'dt': 1704006000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1014.71,
#     'no': 84.94,
#     'no2': 53.47,
#     'o3': 0.82,
#     'so2': 30.99,
#     'pm2_5': 143.63,
#     'pm10': 149.78,
#     'nh3': 6.52},
#    'dt': 1704009600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1041.41,
#     'no': 88.51,
#     'no2': 56.21,
#     'o3': 1.68,
#     'so2': 31.47,
#     'pm2_5': 147.73,
#     'pm10': 155.05,
#     'nh3': 4.94},
#    'dt': 1704013200},
#   {'main': {'aqi': 5},
#    'components': {'co': 827.79,
#     'no': 53.64,
#     'no2': 63.75,
#     'o3': 5.54,
#     'so2': 49.59,
#     'pm2_5': 129.14,
#     'pm10': 136.03,
#     'nh3': 2.44},
#    'dt': 1704016800},
#   {'main': {'aqi': 5},
#    'components': {'co': 734.33,
#     'no': 39.34,
#     'no2': 63.75,
#     'o3': 6.8,
#     'so2': 50.07,
#     'pm2_5': 119.4,
#     'pm10': 125.84,
#     'nh3': 1.96},
#    'dt': 1704020400},
#   {'main': {'aqi': 5},
#    'components': {'co': 674.25,
#     'no': 30.4,
#     'no2': 65.8,
#     'o3': 6.44,
#     'so2': 48.16,
#     'pm2_5': 111.01,
#     'pm10': 116.98,
#     'nh3': 1.08},
#    'dt': 1704024000},
#   {'main': {'aqi': 5},
#    'components': {'co': 727.65,
#     'no': 39.34,
#     'no2': 67.86,
#     'o3': 6.17,
#     'so2': 46.73,
#     'pm2_5': 120.16,
#     'pm10': 126.95,
#     'nh3': 2.15},
#    'dt': 1704027600},
#   {'main': {'aqi': 5},
#    'components': {'co': 867.84,
#     'no': 60.8,
#     'no2': 74.03,
#     'o3': 1.7,
#     'so2': 46.73,
#     'pm2_5': 143.77,
#     'pm10': 152.36,
#     'nh3': 4.31},
#    'dt': 1704031200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1014.71,
#     'no': 88.51,
#     'no2': 79.51,
#     'o3': 0.04,
#     'so2': 49.59,
#     'pm2_5': 164.77,
#     'pm10': 174.76,
#     'nh3': 6.14},
#    'dt': 1704034800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1148.22,
#     'no': 116.23,
#     'no2': 83.63,
#     'o3': 0,
#     'so2': 61.99,
#     'pm2_5': 179.78,
#     'pm10': 190.93,
#     'nh3': 8.87},
#    'dt': 1704038400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1228.33,
#     'no': 128.75,
#     'no2': 85,
#     'o3': 0,
#     'so2': 75.34,
#     'pm2_5': 191.17,
#     'pm10': 203.48,
#     'nh3': 12.16},
#    'dt': 1704042000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1255.04,
#     'no': 130.53,
#     'no2': 82.94,
#     'o3': 0,
#     'so2': 83.92,
#     'pm2_5': 200.38,
#     'pm10': 214.09,
#     'nh3': 15.96},
#    'dt': 1704045600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1255.04,
#     'no': 118.02,
#     'no2': 81.57,
#     'o3': 0,
#     'so2': 91.55,
#     'pm2_5': 206.44,
#     'pm10': 221.07,
#     'nh3': 19.76},
#    'dt': 1704049200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1201.63,
#     'no': 95.67,
#     'no2': 81.57,
#     'o3': 0,
#     'so2': 94.41,
#     'pm2_5': 206.96,
#     'pm10': 221.7,
#     'nh3': 23.31},
#    'dt': 1704052800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1094.82,
#     'no': 70.63,
#     'no2': 79.51,
#     'o3': 0,
#     'so2': 88.69,
#     'pm2_5': 194.14,
#     'pm10': 207.94,
#     'nh3': 25.59},
#    'dt': 1704056400},
#   {'main': {'aqi': 5},
#    'components': {'co': 974.66,
#     'no': 50.96,
#     'no2': 74.03,
#     'o3': 0,
#     'so2': 68.67,
#     'pm2_5': 172.34,
#     'pm10': 184.39,
#     'nh3': 23.05},
#    'dt': 1704060000},
#   {'main': {'aqi': 5},
#    'components': {'co': 881.2,
#     'no': 36.66,
#     'no2': 69.23,
#     'o3': 0,
#     'so2': 51.98,
#     'pm2_5': 156.17,
#     'pm10': 166.59,
#     'nh3': 18.75},
#    'dt': 1704063600},
#   {'main': {'aqi': 5},
#    'components': {'co': 801.09,
#     'no': 23.92,
#     'no2': 65.12,
#     'o3': 0.01,
#     'so2': 40.53,
#     'pm2_5': 144.46,
#     'pm10': 153.37,
#     'nh3': 14.31},
#    'dt': 1704067200},
#   {'main': {'aqi': 5},
#    'components': {'co': 720.98,
#     'no': 14.75,
#     'no2': 58.95,
#     'o3': 0.05,
#     'so2': 30.99,
#     'pm2_5': 131.9,
#     'pm10': 139.75,
#     'nh3': 10.77},
#    'dt': 1704070800},
#   {'main': {'aqi': 5},
#    'components': {'co': 660.9,
#     'no': 9.84,
#     'no2': 52.78,
#     'o3': 0.13,
#     'so2': 28.13,
#     'pm2_5': 122.93,
#     'pm10': 130.32,
#     'nh3': 9.5},
#    'dt': 1704074400},
#   {'main': {'aqi': 5},
#    'components': {'co': 634.19,
#     'no': 8.16,
#     'no2': 47.98,
#     'o3': 0.19,
#     'so2': 30.52,
#     'pm2_5': 118.54,
#     'pm10': 125.64,
#     'nh3': 10.77},
#    'dt': 1704078000},
#   {'main': {'aqi': 5},
#    'components': {'co': 620.84,
#     'no': 9.16,
#     'no2': 43.53,
#     'o3': 0.22,
#     'so2': 32.42,
#     'pm2_5': 115.21,
#     'pm10': 122.2,
#     'nh3': 11.78},
#    'dt': 1704081600},
#   {'main': {'aqi': 5},
#    'components': {'co': 687.6,
#     'no': 22.58,
#     'no2': 41.81,
#     'o3': 0.03,
#     'so2': 37.19,
#     'pm2_5': 122.72,
#     'pm10': 131.04,
#     'nh3': 13.05},
#    'dt': 1704085200},
#   {'main': {'aqi': 5},
#    'components': {'co': 854.49,
#     'no': 54.09,
#     'no2': 44.55,
#     'o3': 0.07,
#     'so2': 41.01,
#     'pm2_5': 142.08,
#     'pm10': 152.84,
#     'nh3': 13.3},
#    'dt': 1704088800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1028.06,
#     'no': 83.15,
#     'no2': 47.3,
#     'o3': 1.17,
#     'so2': 33.85,
#     'pm2_5': 162.87,
#     'pm10': 175.25,
#     'nh3': 8.04},
#    'dt': 1704092400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1068.12,
#     'no': 89.41,
#     'no2': 46.61,
#     'o3': 3.17,
#     'so2': 31.47,
#     'pm2_5': 172.92,
#     'pm10': 185.88,
#     'nh3': 6.4},
#    'dt': 1704096000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1041.41,
#     'no': 81.36,
#     'no2': 45.93,
#     'o3': 5.41,
#     'so2': 30.99,
#     'pm2_5': 170.29,
#     'pm10': 183.14,
#     'nh3': 5.89},
#    'dt': 1704099600},
#   {'main': {'aqi': 5},
#    'components': {'co': 821.11,
#     'no': 50.07,
#     'no2': 47.98,
#     'o3': 10.73,
#     'so2': 38.62,
#     'pm2_5': 129.92,
#     'pm10': 139.06,
#     'nh3': 5.07},
#    'dt': 1704103200},
#   {'main': {'aqi': 5},
#    'components': {'co': 881.2,
#     'no': 59.9,
#     'no2': 58.95,
#     'o3': 10.55,
#     'so2': 54.36,
#     'pm2_5': 135.6,
#     'pm10': 145.44,
#     'nh3': 7.6},
#    'dt': 1704106800},
#   {'main': {'aqi': 5},
#    'components': {'co': 988.01,
#     'no': 76,
#     'no2': 70.6,
#     'o3': 7.51,
#     'so2': 68.67,
#     'pm2_5': 148.56,
#     'pm10': 159.67,
#     'nh3': 10.26},
#    'dt': 1704110400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1094.82,
#     'no': 93.88,
#     'no2': 80.2,
#     'o3': 3.98,
#     'so2': 80.11,
#     'pm2_5': 159.72,
#     'pm10': 172.11,
#     'nh3': 12.92},
#    'dt': 1704114000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1201.63,
#     'no': 113.55,
#     'no2': 87.05,
#     'o3': 1.01,
#     'so2': 90.6,
#     'pm2_5': 169.7,
#     'pm10': 183.37,
#     'nh3': 15.71},
#    'dt': 1704117600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1321.79,
#     'no': 139.48,
#     'no2': 91.85,
#     'o3': 0.04,
#     'so2': 98.23,
#     'pm2_5': 179.3,
#     'pm10': 194.48,
#     'nh3': 18.75},
#    'dt': 1704121200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1375.2,
#     'no': 150.2,
#     'no2': 94.59,
#     'o3': 0,
#     'so2': 97.28,
#     'pm2_5': 179.44,
#     'pm10': 195.32,
#     'nh3': 21.03},
#    'dt': 1704124800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1375.2,
#     'no': 144.84,
#     'no2': 94.59,
#     'o3': 0,
#     'so2': 97.28,
#     'pm2_5': 185.32,
#     'pm10': 202.6,
#     'nh3': 23.56},
#    'dt': 1704128400}]}

# %%
df_current = pd_init.create_dataframe_from_response(current_response['list'])

# %%
df_current
# Out:
#             datetimes  air_quality_index  concentration_of_CO_μg/m3  \
# 0 2023-12-28 18:42:04                  5                    1108.17
#
#    concentration_of_NO_μg/m3  concentration_of_NO2_μg/m3  \
# 0                       91.2                       77.46
#
#    concentration_of_O3_μg/m3  concentration_of_SO2_μg/m3  \
# 0                          0                       80.11
#
#    concentration_of_PM2_5_μg/m3  concentration_of_PM10_μg/m3  \
# 0                        154.36                       170.36
#
#    concentration_of_NH3_μg/m3
# 0                       26.09

# %%
df_forecast = pd_init.create_dataframe_from_response(forecast_response['list'])

# %%
df_forecast.sample(3)
# Out:
#              datetimes  air_quality_index  concentration_of_CO_μg/m3  \
# 28 2023-12-29 22:00:00                  5                    1348.50
# 57 2023-12-31 03:00:00                  5                     667.57
# 74 2023-12-31 20:00:00                  5                    1201.63
#
#     concentration_of_NO_μg/m3  concentration_of_NO2_μg/m3  \
# 28                     110.87                       78.14
# 57                      16.09                       44.55
# 74                      95.67                       81.57
#
#     concentration_of_O3_μg/m3  concentration_of_SO2_μg/m3  \
# 28                       0.00                       55.79
# 57                       0.04                       30.28
# 74                       0.00                       94.41
#
#     concentration_of_PM2_5_μg/m3  concentration_of_PM10_μg/m3  \
# 28                        198.43                       219.36
# 57                        100.53                       104.66
# 74                        206.96                       221.70
#
#     concentration_of_NH3_μg/m3
# 28                       13.05
# 57                        9.63
# 74                       23.31

# %%
df_historical = pd_init.create_dataframe_from_response(historical_response['list'])

# %%
df_historical.sample(3)
# Out:
#                 datetimes  air_quality_index  concentration_of_CO_μg/m3  \
# 21993 2023-07-14 01:00:00                  1                     240.33
# 1780  2021-03-13 20:00:00                  5                    1054.76
# 15523 2022-10-11 11:00:00                  2                     250.34
#
#        concentration_of_NO_μg/m3  concentration_of_NO2_μg/m3  \
# 21993                       0.08                       13.88
# 1780                       80.47                       83.63
# 15523                       4.97                       15.59
#
#        concentration_of_O3_μg/m3  concentration_of_SO2_μg/m3  \
# 21993                      15.02                        3.87
# 1780                        0.00                       33.38
# 15523                      89.41                       14.42
#
#        concentration_of_PM2_5_μg/m3  concentration_of_PM10_μg/m3  \
# 21993                          6.71                         8.11
# 1780                         106.06                       119.52
# 15523                         15.77                        17.48
#
#        concentration_of_NH3_μg/m3
# 21993                        9.75
# 1780                        25.84
# 15523                        1.04
